# %% [markdown]
# First, let's load the libraties that will be used for the analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# We will start by having a general overview of what is available in the database.

# %%
data = pd.read_csv('all_data.csv')
print(data.info())
print(data.describe())
print(data.Country.unique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB
# None
#               Year  Life expectancy at birth (years)           GDP
# count    96.000000                         96.000000  9.600000e+01
# mean   2007.500000                         72.789583  3.880499e+12
# std       4.633971                         10.672882  5.197561e+12
# min    2000.000000                         44.300000  4.415703e+09
# 25%    2003.750000                         74.475000  1.733018e+11
# 50%    2007.500000                         76.750000  1.280220e+12
# 75%    2011.250000                         78.900000  4.067510e+12
# max    2015.000000                         81.000000  1.810000e+13
# ['Chile' 'China' 'Germany' 'Mexico' 'United States of America' 'Zimbabwe']

# %% [markdown]
# We change the variable types to be more efficient on the memory usage.

# %%
data.rename(columns={'Life expectancy at birth (years)':'Life Expectancy'}, inplace=True)
data = data.astype({'Year': 'int32', 'Life Expectancy': 'float32', 'GDP': 'float32'})
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          96 non-null     object
#  1   Year             96 non-null     int32
#  2   Life Expectancy  96 non-null     float32
#  3   GDP              96 non-null     float32
# dtypes: float32(2), int32(1), object(1)
# memory usage: 2.0+ KB
# None

# %% [markdown]
# As I come from Mexico first we will see how Life Expectancy and the GDP have change through time and if there is any relation.

# %%
data_Mexico = data[data.Country == 'Mexico']
sns.lineplot(x=data_Mexico['Year'], y=data_Mexico['Life Expectancy'])
plt.title('Life Expectancy VS Year in Mexico')

plt.figure()
sns.lineplot(x=data_Mexico['Year'], y=data_Mexico['GDP'])

plt.figure()
sns.lineplot(x=data_Mexico['GDP'], y=data_Mexico['Life Expectancy'])
# Out:
# <Axes: xlabel='GDP', ylabel='Life Expectancy'>

# %% [markdown]
# Now we will start comparing countries.

# %%
sns.scatterplot(x=data['Year'], y=data['Life Expectancy'], hue=data['Country'])

plt.figure()
sns.scatterplot(x='Year', y='GDP', hue='Country', data=data)

plt.figure()
sns.scatterplot(x='GDP', y='Life Expectancy', hue='Country', data=data)
# Out:
# <Axes: xlabel='GDP', ylabel='Life Expectancy'>
